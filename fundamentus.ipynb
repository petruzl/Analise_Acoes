# %%
import fundamentus
import requests_cache
import requests
import time, logging
import pandas as pd
import matplotlib.pyplot as plt

# %%
import fundamentus

main_pipeline = fundamentus.Pipeline('WEGE3')
response = main_pipeline.get_all_information()

# Extract the information from the response.
price_information = response.transformed_information['price_information']
detailed_information = response.transformed_information['detailed_information']
oscillations = response.transformed_information['oscillations']
valuation_indicators = response.transformed_information['valuation_indicators']
profitability_indicators = response.transformed_information['profitability_indicators']
indebtedness_indicators = response.transformed_information['indebtedness_indicators']
balance_sheet = response.transformed_information['balance_sheet']
income_statement = response.transformed_information['income_statement']

# %%
# Out:
# TransformContract(transformed_information={'stock_identification': {'name': InformationItem(title='Código', tooltip='Código da ação.', value='WEGE3'), 'ticker': InformationItem(title='Empresa', tooltip='Nome comercial da empresa.', value='WEG SA')}, 'financial_summary': {'market_valuation': InformationItem(title='Valor de mercado', tooltip='Valor de mercado da empresa, calculado multiplicando o preço da ação pelo número total de ações.', value=Decimal('173433000000')), 'enterprise_valuation': InformationItem(title='Valor da firma', tooltip='Valor da firma (Enterprise Value) é calculado somando o valor de mercado da empresa a sua dívida líquida.', value=Decimal('171011000000')), 'number_of_shares': InformationItem(title='Nº de ações', tooltip='Número total de ações, somadas todas as espécies: ON, PN, etc.', value=Decimal('4197320000')), 'last_financial_statement': InformationItem(title='Último balanço', tooltip='Data do último balanço divulgado pela empresa que consta no nosso banco de dados. Todos os indicadores são calculados considerando os últimos 12 meses finalizados na data deste balanço.', value='31/03/2025'), 'sector': InformationItem(title='Setor', tooltip='Classificação setorial.', value='Máquinas e Equipamentos'), 'subsector': InformationItem(title='Subsetor', tooltip='Classificação por segmento de atuação.', value='Motores, Compressores e Outros')}, 'price_information': {'price': InformationItem(title='Cotação', tooltip='Cotação de fechamento da ação no último pregão.', value=Decimal('41.32')), 'date': InformationItem(title='Última cotação', tooltip='Data do último pregão em  que o ativo foi negociado.', value='22/07/2025')}, 'detailed_information': {'stock_type': InformationItem(title='Tipo', tooltip='ON = Ordinária, PN = Preferencial, PNA = Pref. tipo A, etc.', value='ON N1'), 'traded_volume_per_day': InformationItem(title='Volume negociado por dia', tooltip='Valor médio de negociação diária da ação, considerando os últimos 2 meses (R$).', value=Decimal('327267000')), 'equity_value_per_share': InformationItem(title='VPA', tooltip='Valor Patrimonial por Ação: Valor do Patrimônio Líquido dividido pelo número total de ações.', value=Decimal('5.07')), 'earnings_per_share': InformationItem(title='LPA', tooltip='Lucro por Ação.', value=Decimal('1.49')), 'variation_52_weeks': {'lowest_value': InformationItem(title='Mínimo', tooltip='Menor cotação da ação nos últimos 12 meses.', value=Decimal('39.53')), 'highest_value': InformationItem(title='Máximo', tooltip='Maior cotação da ação nos últimos 12 meses.', value=Decimal('57.92'))}}, 'oscillations': {'variation_day': InformationItem(title='dia', tooltip='', value=Decimal('-0.0155')), 'variation_month': InformationItem(title='mês', tooltip='', value=Decimal('-0.0243')), 'variation_30_days': InformationItem(title='30 dias', tooltip='', value=Decimal('-0.0058')), 'variation_12_months': InformationItem(title='12 meses', tooltip='', value=Decimal('-0.1124')), 'variation_2022': InformationItem(title='2025', tooltip='', value=Decimal('-0.2094')), 'variation_2021': InformationItem(title='2024', tooltip='', value=Decimal('0.4543')), 'variation_2020': InformationItem(title='2023', tooltip='', value=Decimal('-0.027')), 'variation_2019': InformationItem(title='2022', tooltip='', value=Decimal('0.1875')), 'variation_2018': InformationItem(title='2021', tooltip='', value=Decimal('-0.1202')), 'variation_2017': InformationItem(title='2020', tooltip='', value=Decimal('1.169'))}, 'valuation_indicators': {'price_divided_by_profit_title': InformationItem(title='P/L', tooltip='Preço da ação dividido pelo lucro por ação. O P/L é o número de anos que se levaria para reaver o capital aplicado na compra de uma ação, através do recebimento do lucro gerado pela empresa, considerando que esses lucros permaneçam constantes.', value=Decimal('27.70')), 'price_divided_by_asset_value': InformationItem(title='P/VP', tooltip='Preço da ação dividido pelo Valor Patrimonial por ação. Informa quanto o mercado es ...

# %%
# Out:
# TransformContract(transformed_information={'stock_identification': {'name': InformationItem(title='Código', tooltip='Código da ação.', value='WEGE3'), 'ticker': InformationItem(title='Empresa', tooltip='Nome comercial da empresa.', value='WEG SA')}, 'financial_summary': {'market_valuation': InformationItem(title='Valor de mercado', tooltip='Valor de mercado da empresa, calculado multiplicando o preço da ação pelo número total de ações.', value=Decimal('173433000000')), 'enterprise_valuation': InformationItem(title='Valor da firma', tooltip='Valor da firma (Enterprise Value) é calculado somando o valor de mercado da empresa a sua dívida líquida.', value=Decimal('171011000000')), 'number_of_shares': InformationItem(title='Nº de ações', tooltip='Número total de ações, somadas todas as espécies: ON, PN, etc.', value=Decimal('4197320000')), 'last_financial_statement': InformationItem(title='Último balanço', tooltip='Data do último balanço divulgado pela empresa que consta no nosso banco de dados. Todos os indicadores são calculados considerando os últimos 12 meses finalizados na data deste balanço.', value='31/03/2025'), 'sector': InformationItem(title='Setor', tooltip='Classificação setorial.', value='Máquinas e Equipamentos'), 'subsector': InformationItem(title='Subsetor', tooltip='Classificação por segmento de atuação.', value='Motores, Compressores e Outros')}, 'price_information': {'price': InformationItem(title='Cotação', tooltip='Cotação de fechamento da ação no último pregão.', value=Decimal('41.32')), 'date': InformationItem(title='Última cotação', tooltip='Data do último pregão em  que o ativo foi negociado.', value='22/07/2025')}, 'detailed_information': {'stock_type': InformationItem(title='Tipo', tooltip='ON = Ordinária, PN = Preferencial, PNA = Pref. tipo A, etc.', value='ON N1'), 'traded_volume_per_day': InformationItem(title='Volume negociado por dia', tooltip='Valor médio de negociação diária da ação, considerando os últimos 2 meses (R$).', value=Decimal('327267000')), 'equity_value_per_share': InformationItem(title='VPA', tooltip='Valor Patrimonial por Ação: Valor do Patrimônio Líquido dividido pelo número total de ações.', value=Decimal('5.07')), 'earnings_per_share': InformationItem(title='LPA', tooltip='Lucro por Ação.', value=Decimal('1.49')), 'variation_52_weeks': {'lowest_value': InformationItem(title='Mínimo', tooltip='Menor cotação da ação nos últimos 12 meses.', value=Decimal('39.53')), 'highest_value': InformationItem(title='Máximo', tooltip='Maior cotação da ação nos últimos 12 meses.', value=Decimal('57.92'))}}, 'oscillations': {'variation_day': InformationItem(title='dia', tooltip='', value=Decimal('-0.0155')), 'variation_month': InformationItem(title='mês', tooltip='', value=Decimal('-0.0243')), 'variation_30_days': InformationItem(title='30 dias', tooltip='', value=Decimal('-0.0058')), 'variation_12_months': InformationItem(title='12 meses', tooltip='', value=Decimal('-0.1124')), 'variation_2022': InformationItem(title='2025', tooltip='', value=Decimal('-0.2094')), 'variation_2021': InformationItem(title='2024', tooltip='', value=Decimal('0.4543')), 'variation_2020': InformationItem(title='2023', tooltip='', value=Decimal('-0.027')), 'variation_2019': InformationItem(title='2022', tooltip='', value=Decimal('0.1875')), 'variation_2018': InformationItem(title='2021', tooltip='', value=Decimal('-0.1202')), 'variation_2017': InformationItem(title='2020', tooltip='', value=Decimal('1.169'))}, 'valuation_indicators': {'price_divided_by_profit_title': InformationItem(title='P/L', tooltip='Preço da ação dividido pelo lucro por ação. O P/L é o número de anos que se levaria para reaver o capital aplicado na compra de uma ação, através do recebimento do lucro gerado pela empresa, considerando que esses lucros permaneçam constantes.', value=Decimal('27.70')), 'price_divided_by_asset_value': InformationItem(title='P/VP', tooltip='Preço da ação dividido pelo Valor Patrimonial por ação. Informa quanto o mercado es ...
