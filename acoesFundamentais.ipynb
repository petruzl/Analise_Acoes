# %%
import fundamentus
import requests_cache
import requests
import time, logging
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://www.infomoney.com.br/cotacoes/empresas-b3/'
tables = pd.read_html(url)
acoes = tables[1]['Ativos']
print(acoes)
# Out:
# 0       AZZA3
# 1       ALOS3
# 2       VIIA3
# 3      CEDO4F
# 4     NFLX34F
# 5     NIKE34F
# 6     MCDC34F
# 7     HOME34F
# 8     FDMO34F
# 9     CMCS34F
# 10    AMZO34F
# 11     RDNI3F
# 12     SLED4F
# 13     RSID3F
# 14     MNDL3F
# 15     LEVE3F
# 16     CTKA4F
# 17     MYPK3F
# 18     GRND3F
# 19     LCAM3F
# 20      CEAB3
# 21     VSTE3F
# 22     CGRA3F
# 23     ESTR4F
# 24     DIRR3F
# 25     CTNM3F
# 26     ANIM3F
# 27     EVEN3F
# 28     AMAR3F
# 29     MOVI3F
# 30     JHSF3F
# 31     HBOR3F
# 32     PDGR3F
# 33     ARZZ3F
# 34     EZTC3F
# 35     ALPA3F
# 36     RENT3F
# 37     MRVE3F
# 38     MGLU3F
# 39     LREN3F
# 40     COGN3F
# 41      WHRL4
# 42      WHRL3
# 43      TCSA3
# 44     SBUB34
# 45      SMLS3
# 46      SEER3
# 47      SLED4
# 48      HOOT4
# 49      GFSA3
# 50      YDUQ3
# 51      CYRE3
# 52      CVCB3
# 53     SBFG3F
# Name: Ativos, dtype: object

# %%
df = fundamentus.get_resultado()
print(df.head())
df
# Out:
# Multiples  cotacao      pl   pvp    psr      dy     pa    pcg  pebit   pacl  \
# papel
# AALR3         4.99  -10.83  0.71  0.611  0.0000  0.266 -60.26   6.15  -0.75
# ABCB3         0.00    0.00  0.00  0.000  0.0000  0.000   0.00   0.00   0.00
# ABCB4        20.77    5.22  0.79  0.000  0.0937  0.000   0.00   0.00   0.00
# ABEV3        13.59   14.84  2.27  2.337  0.0679  1.454  50.91  10.58 -25.89
# ABYA3         4.91 -214.80  1.76  2.055  0.0000  0.527   1.98  19.96  -2.75
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# AALR3       10.54      5.63   0.0994 -0.0495  0.0474 -0.0653  0.98
# ABCB3        0.00      0.00   0.0000  0.0000  0.0000  0.1505  0.00
# ABCB4        0.00      0.00   0.0000  0.0000  0.0000  0.1505  0.00
# ABEV3        9.73      7.28   0.2209  0.1620  0.1919  0.1527  1.11
# ABYA3       33.67     33.67   0.1029 -0.0096  0.0278 -0.0082  2.09
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# ...

# %%
df.columns
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
filtro = df[(df.pvp<1) & (df.dy > 0.05)]
print(filtro)
filtro
# Salvar como Excel (requer openpyxl instalado)
filtro.to_excel("filtro_fundamentalista.xlsx", index=True)
# Out:
# Multiples  cotacao     pl   pvp    psr      dy     pa   pcg  pebit  pacl  \
# papel
# ABCB4        20.77   5.22  0.79  0.000  0.0937  0.000  0.00   0.00  0.00
# AGRO3        20.43   6.78  0.97  1.548  0.0762  0.528  4.54   5.17 -3.83
# ALLD3         6.91   5.91  0.41  0.123  0.1864  0.190  0.58   5.38  1.09
# ALOS3        21.52  13.55  0.87  4.256  0.0509  0.439  4.54   8.80 -1.38
# ANIM3         3.65  12.67  0.62  0.383  0.1438  0.148  1.23   1.39 -0.31
# ...            ...    ...   ...    ...     ...    ...   ...    ...   ...
# TKNO4        77.71   4.77  0.71  0.769  0.0907  0.559  1.33   5.33  1.45
# TPIS3         4.03   8.78  0.19  0.137  0.0572  0.065 -0.15   0.74 -0.11
# TRPN3         0.71   0.44  0.54  0.263  1.0474  0.399  0.59   0.36  0.59
# TUPY3        17.18 -53.20  0.69  0.216  0.0882  0.213  0.58   2.69 -4.15
# UCAS3         1.40  21.91  0.50  0.416  0.1297  0.238  3.20 -14.01 -1.19
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# ...

# %%
filtro.shape
# Out:
# (63, 20)

# %%
filtro.sort_values('dy', ascending=False, inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13680\160807480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtro.sort_values('dy', ascending=False, inplace=True)

# %%
filtro.head()
# Out:
# Multiples  cotacao    pl   pvp    psr       dy     pa   pcg  pebit  pacl  \
# papel
# BRPR3       131.17 -0.57  0.05  0.695  12.0289  0.038  1.73  12.11 -0.49
# SYNE3         6.60  1.80  0.92  0.758   1.0621  0.318  1.03   2.15 -8.45
# TRPN3         0.71  0.44  0.54  0.263   1.0474  0.399  0.59   0.36  0.59
# JBSS3        39.03  3.11  0.78  0.077   0.3927  0.141  0.88   1.31 -0.37
# BPAT33       20.00  0.00  0.82  0.000   0.3572  0.000  0.00   0.00  0.00
#
# Multiples  evebit  evebitda  mrgebit  mrgliq    roic     roe  liqc  \
# papel
# BRPR3       -3.70     -2.55   0.0574 -1.2398  0.0035 -0.0934  1.12
# SYNE3        3.00      2.57   0.3533  0.5048  0.1726  0.5113  5.43
# TRPN3       -0.35     -0.35   0.7228  0.5929  5.2301  1.2235  3.61
# JBSS3        4.58      3.11   0.0586  0.0275  0.1470  0.2515  1.62
# BPAT33       0.00      0.00   0.0000  0.0000  0.0000  0.0000  0.00
#
# Multiples        liq2m       patrliq  divbpatr     c5y
# papel
# ...

# %%
filtro.index
# Out:
# Index(['BRPR3', 'SYNE3', 'TRPN3', 'JBSS3', 'BPAT33', 'MELK3', 'PATI4', 'MMAQ4',
#        'HBTS5', 'ALLD3', 'RECV3', 'ANIM3', 'BGIP4', 'MTRE3', 'UCAS3', 'BRAP3',
#        'BRAP4', 'BBAS3', 'CGRA3', 'CGRA4', 'BAZA3', 'ISAE4', 'BGIP3', 'SCAR3',
#        'BRSR6', 'LOGG3', 'ROMI3', 'BRSR3', 'ABCB4', 'TKNO4', 'TUPY3', 'EZTC3',
#        'BRSR5', 'BMKS3', 'RPAD5', 'BALM4', 'BMIN4', 'BBDC3', 'BMGB4', 'JSLG3',
#        'JHSF3', 'AGRO3', 'FESA4', 'PFRM3', 'CLSC3', 'SAPR4', 'PGMN3', 'MTSA4',
#        'POSI3', 'SAPR11', 'CSNA3', 'DEXP4', 'BNBR3', 'DEXP3', 'CAML3', 'TPIS3',
#        'PTNT4', 'EVEN3', 'MERC4', 'SAPR3', 'LVTC3', 'SMTO3', 'ALOS3'],
#       dtype='object', name='papel')

# %%
filtro.columns
# Out:
# Index(['cotacao', 'pl', 'pvp', 'psr', 'dy', 'pa', 'pcg', 'pebit', 'pacl',
#        'evebit', 'evebitda', 'mrgebit', 'mrgliq', 'roic', 'roe', 'liqc',
#        'liq2m', 'patrliq', 'divbpatr', 'c5y'],
#       dtype='object', name='Multiples')

# %%
plt.figure(figsize=(20,6));
plt.bar(filtro.index, filtro.dy);
plt.xticks(rotation=45);
plt.title("Açoes com pvp<1 e dy > 0.05")
# Out:
# Text(0.5, 1.0, 'Açoes com pvp<1 e dy > 0.05')
